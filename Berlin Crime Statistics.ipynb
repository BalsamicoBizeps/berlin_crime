# %%
import pandas as pd
import seaborn as sn
import matplotlib as plt
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Testing data for crime hospots</h1>

# %%
# Import data sets created in SQL as csv

df_hotspots= pd.read_csv('/Users/janoskamke/Documents/GitHub/berlin_crime/crimehotspots.csv', sep = ';')
df_hotspots.head(10)
# Out:
#                   location  total_robbery  total_street_robbery  total_injury  \
# 0           Alexanderplatz         1450.0                 855.0       12330.0
# 1     Tempelhofer Vorstadt          988.0                 525.0        6855.0
# 2  Frankfurter Allee Sd FK         1052.0                 648.0        7357.0
# 3           Schneberg-Nord         1299.0                 760.0        6165.0
# 4          Wedding Zentrum         1045.0                 560.0        8442.0
# 5  Neukllner Mitte/Zentrum          863.0                 412.0        6323.0
# 6   Sdliche Friedrichstadt         1038.0                 589.0        5475.0
# 7                Tempelhof          569.0                 250.0        5431.0
# 8            Kurfrstendamm          791.0                 368.0        6764.0
# 9               Moabit Ost          545.0                 302.0        5191.0
#
#    total_agg_assault  total_threat  total_theft  total_car  total_from_car  \
# ...

# %%
# Your DataFrame
data = {
    'location': ['Alexanderplatz', 'Tempelhofer Vorstadt', 'Frankfurter Allee Sd FK', 'Schneberg-Nord', 
                 'Wedding Zentrum', 'Neukllner Mitte/Zentrum', 'Sdliche Friedrichstadt', 'Tempelhof', 
                 'Kurfrstendamm', 'Moabit Ost'],
    'total_robbery': [1450, 988, 1052, 1299, 1045, 863, 1038, 569, 791, 545]
}

df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df['location'], df['total_robbery'], color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total Robbery')
plt.title('Total Robbery per Location')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_robbery = df_hotspots.sort_values(by='total_robbery', ascending=False)


# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df_robbery["location"].head(10), df_robbery["total_robbery"].head(10), color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total Robbery')
plt.title('Total Robbery per Neigbourhood')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_assault = df_hotspots.sort_values(by='total_bulgary', ascending=False)


# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df_assault["location"].head(10), df_assault["total_bulgary"].head(10), color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total Burglaries')
plt.title('Total Burglaries per Neigbourhood')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_assault = df_hotspots.sort_values(by='total_agg_assault', ascending=False)


# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df_assault["location"].head(10), df_assault["total_agg_assault"].head(10), color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total Aggravated Assault')
plt.title('Total Aggravated Assault per Neigbourhood')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_bike = df_hotspots.sort_values(by='total_bike', ascending=False)


# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df_bike["location"].head(15), df_bike["total_bike"].head(15), color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total Bike Theft')
plt.title('Total Bike Theft per Neigbourhood')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_drugs = df_hotspots.sort_values(by='total_drugs', ascending=False)


# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df_drugs["location"].head(15), df_drugs["total_drugs"].head(15), color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total Drug related crimes')
plt.title('Total Drug related crimes per Neigbourhood')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_hotspots['total_crimes'] = df_hotspots[['total_robbery', "total_street_robbery", 'total_injury', "total_agg_assault", "total_threat", 'total_theft', "total_car", "total_from_car", "total_bike", "total_bulgary", "total_fire", "total_arson", "total_damage", "total_graffiti", "total_drugs"]].sum(axis=1)
df_hotspots
# Out:
#                                      location  total_robbery  \
# 0                              Alexanderplatz         1450.0
# 1                        Tempelhofer Vorstadt          988.0
# 2                     Frankfurter Allee Sd FK         1052.0
# 3                              Schneberg-Nord         1299.0
# 4                             Wedding Zentrum         1045.0
# ..                                        ...            ...
# 145                           Allende-Viertel           15.0
# 146        Malchow, Wartenberg und Falkenberg           14.0
# 147  Schmckwitz/Karolinenhof/Rauchfangswerder            6.0
# 148                                 Mggelheim            5.0
# 149                           Forst Grunewald           16.0
#
#      total_street_robbery  total_injury  total_agg_assault  total_threat  \
# 0                   855.0       12330.0             3292.0        2666.0
# 1                   525.0        6855.0             2004.0        1979.0
# ...

# %%
df_total = df_hotspots.sort_values(by='total_crimes', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df_total["location"].head(15), df_total["total_crimes"].head(15), color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total crimes')
plt.title('Total crimes per Neigbourhood')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_districts = pd.read_csv('/Users/janoskamke/Documents/GitHub/berlin_crime/district_and_types.csv', sep = ';')
df_districts.head(10)
# Out:
#                          name  total_robbery  total_street_robbery  \
# 0                       Mitte         7582.0                4225.0
# 1    Friedrichshain-Kreuzberg         6748.0                4310.0
# 2                      Pankow         2581.0                1304.0
# 3  Charlottenburg-Wilmersdorf         4220.0                2039.0
# 4                     Spandau         2314.0                1193.0
# 5         Steglitz-Zehlendorf         1624.0                 794.0
# 6         Tempelhof-Schneberg         3525.0                1906.0
# 7                     Neuklln         4659.0                2545.0
# 8             Treptow-Kpenick         1571.0                 859.0
# 9         Marzahn-Hellersdorf         1981.0                1090.0
#
#    total_injury  total_agg_assault  total_threat  total_theft  total_car  \
# 0       59628.0            15730.0       17130.0     328450.0     4186.0
# 1       37719.0            12220.0        9244.0     213388.0     3667.0
# ...

# %%
df_districts['total_crimes'] = df_districts[['total_robbery', "total_street_robbery", 'total_injury', "total_agg_assault", "total_threat", 'total_theft', "total_car", "total_from_car", "total_bike", "total_bulgary", "total_fire", "total_arson", "total_damage", "total_graffiti", "total_drugs"]].sum(axis=1)
df_districts
# Out:
#                           name  total_robbery  total_street_robbery  \
# 0                        Mitte         7582.0                4225.0
# 1     Friedrichshain-Kreuzberg         6748.0                4310.0
# 2                       Pankow         2581.0                1304.0
# 3   Charlottenburg-Wilmersdorf         4220.0                2039.0
# 4                      Spandau         2314.0                1193.0
# 5          Steglitz-Zehlendorf         1624.0                 794.0
# 6          Tempelhof-Schneberg         3525.0                1906.0
# 7                      Neuklln         4659.0                2545.0
# 8              Treptow-Kpenick         1571.0                 859.0
# 9          Marzahn-Hellersdorf         1981.0                1090.0
# 10                 Lichtenberg         1890.0                1057.0
# 11               Reinickendorf         2385.0                1171.0
#
#     total_injury  total_agg_assault  total_threat  total_theft  total_car  \
# ...

# %%
df_total_districs = df_districts.sort_values(by='total_crimes', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(df_total_districs["name"].head(15), df_total_districs["total_crimes"].head(15), color='skyblue')
plt.xlabel('Location')
plt.ylabel('Total crimes')
plt.title('Total crimes per District')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()

# %%
df_total_districs = df_districts.sort_values(by='total_crimes', ascending=False)


# Selecting the row (and excluding the 'name' column)
row_data = df_total_districs.drop(columns ="total_crimes").iloc[0, 1:]  # Selects all columns except 'name'

# Plotting the row as a bar plot
plt.figure(figsize=(12, 6))
row_data.plot(kind='bar', color='skyblue')

# Adding labels and title
plt.ylabel('Number of Crimes')
plt.title(f'Crime Statistics for {df_total_districs.drop(columns ="total_crimes").iloc[0, 0]}')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Selecting the row (and excluding the 'name' column)
row_data = df_total_districs.drop(columns ="total_crimes").iloc[1, 1:]  # Selects all columns except 'name'

# Plotting the row as a bar plot
plt.figure(figsize=(12, 6))
row_data.plot(kind='bar', color='skyblue')

# Adding labels and title
plt.ylabel('Number of Crimes')
plt.title(f'Crime Statistics for {df_total_districs.drop(columns ="total_crimes").iloc[1, 0]}')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Selecting the row (and excluding the 'name' column)
row_data_local = df_hotspots.drop(columns ="total_crimes").iloc[0, 1:]  # Selects all columns except 'name'

# Plotting the row as a bar plot
plt.figure(figsize=(12, 6))
row_data.plot(kind='bar', color='skyblue')

# Adding labels and title
plt.ylabel('Number of Crimes')
plt.title(f'Crime Statistics for {df_hotspots.drop(columns ="total_crimes").iloc[0, 0]}')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Import data sets created in SQL as csv

df_development = pd.read_csv('/Users/janoskamke/Documents/GitHub/berlin_crime/crime_developement.csv', sep = ';')
df_development.head(10)
# Out:
#    year  total_robbery  total_street_robbery  total_injury  total_agg_assault  \
# 0  2012         6283.0                2886.0       42153.0            11032.0
# 1  2013         6088.0                3135.0       41461.0            10247.0
# 2  2014         5583.0                3228.0       39190.0             9515.0
# 3  2015         5318.0                2914.0       39312.0             9664.0
# 4  2016         5046.0                2962.0       41339.0            10024.0
# 5  2017         4165.0                2324.0       42283.0            10608.0
# 6  2018         4202.0                2417.0       42828.0            10656.0
# 7  2019         4395.0                2627.0       43035.0            10754.0
#
#    total_threat  total_theft  total_car  total_from_car  total_bike  \
# 0       14196.0     207340.0     5732.0         30503.0     25836.0
# 1       14333.0     220417.0     6628.0         35652.0     26389.0
# ...

# %%
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(df_development['year'], df_development['total_crimes'], marker='o', linestyle='-', color='b', label='Total Crimes')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Total Crimes')
plt.title('Total Crimes Over the Years')

# Displaying the legend
plt.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(df_development['year'], df_development['total_drugs'], marker='o', linestyle='-', color='b', label='Total Drug related Crime')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Total Drug related Crime')
plt.title('Total Drug related Crimes Over the Years')

# Displaying the legend
plt.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(df_development['year'], df_development['total_bulgary'], marker='o', linestyle='-', color='b', label='Total Burglaries')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Total Burglaries')
plt.title('Total Burglaries Over the Years')

# Displaying the legend
plt.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(df_development['year'], df_development['total_bike'], marker='o', linestyle='-', color='b', label='Total Bike Thefts')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Total Bike Thefts')
plt.title('Total Bike Thefts Over the Years')

# Displaying the legend
plt.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()
